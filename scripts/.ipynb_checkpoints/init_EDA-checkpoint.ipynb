# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import scipy

import seaborn as sns
import bokeh.plotting

sns.set_style("ticks")
sns.set_context("notebook", font_scale=1.5)

# %% [markdown]
# I wanted to just get started with a simple Data Science project, so I found this interesting time-series/categorical dataset from the UCI Machine Learning Repository.
#
# It is "experimental data used for binary classification (room occupancy) from Temperature,Humidity,Light and CO2. Ground-truth occupancy was obtained from time stamped pictures that were taken every minute."
#
# Let's load the data and get started.
# Data source: http://archive.ics.uci.edu/ml/datasets/Occupancy+Detection+

# %%
full_DatFrame = pd.read_csv('../dat/datatraining.txt')
full_DatFrame[:5]
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %%
full_DatFrame[-5:]
# Out:
#                      date  Temperature  Humidity  Light         CO2  \
# 8139  2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000
# 8140  2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000
# 8141  2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000
# 8142  2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333
# 8143  2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000
#
#       HumidityRatio  Occupancy
# 8139       0.005579          1
# 8140       0.005563          1
# 8141       0.005596          1
# 8142       0.005621          1
# 8143       0.005612          1

# %% [markdown]
# We can plot the time-series data of the occupancy.
# Then we can count the number of transitions (i.e. 1 to 0 or 0 to 1) where 1 is occupied and 0 is unoccupied.

# %%
from datetime import datetime

full_DatFrame['date_obj'] = [datetime.strptime(full_DatFrame['date'][i], 
                                               '%Y-%m-%d %H:%M:%S') 
                             for i in np.arange(1,len(full_DatFrame)+1)]
full_DatFrame['secs_since_midnight'] = [(full_DatFrame['date_obj'][i] - full_DatFrame['date_obj'][i].replace(hour=0, minute=0, second=0, microsecond=0)).total_seconds() 
                                        for i in np.arange(1,len(full_DatFrame)+1)]
full_DatFrame[:5]
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy            date_obj  secs_since_midnight
# 1          1 2015-02-04 17:51:00              64260.0
# 2          1 2015-02-04 17:51:59              64319.0
# 3          1 2015-02-04 17:53:00              64380.0
# 4          1 2015-02-04 17:54:00              64440.0
# 5          1 2015-02-04 17:55:00              64500.0

# %%
full_DatFrame[-5:]
# Out:
#                      date  Temperature  Humidity  Light         CO2  \
# 8139  2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000
# 8140  2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000
# 8141  2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000
# 8142  2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333
# 8143  2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000
#
#       HumidityRatio  Occupancy            date_obj  secs_since_midnight
# 8139       0.005579          1 2015-02-10 09:29:00              34140.0
# 8140       0.005563          1 2015-02-10 09:29:59              34199.0
# 8141       0.005596          1 2015-02-10 09:30:59              34259.0
# 8142       0.005621          1 2015-02-10 09:32:00              34320.0
# 8143       0.005612          1 2015-02-10 09:33:00              34380.0

# %%
fig, ax = plt.subplots()
ax.plot(full_DatFrame['Occupancy'])
ax.set_ylabel('Occupancy')
ax.set_xlabel('Time index')
plt.show()

# %%
occup_trj = np.array(full_DatFrame['Occupancy'])
num_trans = (occup_trj[:-1] - occup_trj[1:] != 0).sum()
print("Number of transitions = ", num_trans)
# Out:
# Number of transitions =  40

# %% [markdown]
# Interesting.  The office room has two states: occupied (1) or unoccupied (0), and we can see 40 transitions between these two states.
#
# Given my background in chemical physics, this reminds me of a two state Markov model.

# %%
from IPython.display import Image

# %%
Image("../images/2state_markov.png", width=400)

# %% [markdown]
# The above diagram of the two state Markov process where both foward and reverse transitions are possible.
# k_f and k_r represent the transition rates
#
# * It should be noted that that bringing up Markov processes at this point is a bit premature.  Markov processes have no history depenendence.  In other words the transition probabilities only depend on the current state.  But I do think this is an intuitive way to begin thinking about the problem.
#
# If we are to use a model like this, we should check to see if the unoccupied and occupied states are distinctly different.
# In other words, are the distribution of other attributes (e.g. temperature, humidity, etc) distinctly different?
#
# Let's startby plotting some scatter plots of each state.

# %% [markdown]
# But before we do that we should see if we can reduce the number of attributes we are dealing with.
# We currently have 5 (not counting occupancy), so there are 10 possible pairs of attributes we can plot at a time.
# Let's see if any of them are highly correlated with each other.
#
# * We can probably expect to see that "humidity" and "humidity ratio" are redundant attributes

# %%
df = full_DatFrame.drop(['Occupancy','date'], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %%
df_0 = full_DatFrame[full_DatFrame['Occupancy'] == 0].drop(['date'], axis=1)
df_0[:5]
# Out:
#     Temperature  Humidity  Light    CO2  HumidityRatio  Occupancy  \
# 17       23.000     27.20    0.0  681.5       0.004728          0
# 18       22.945     27.29    0.0  685.0       0.004728          0
# 19       22.945     27.39    0.0  685.0       0.004745          0
# 20       22.890     27.39    0.0  689.0       0.004730          0
# 21       22.890     27.39    0.0  689.5       0.004730          0
#
#               date_obj  secs_since_midnight
# 17 2015-02-04 18:07:00              65220.0
# 18 2015-02-04 18:08:00              65280.0
# 19 2015-02-04 18:08:59              65339.0
# 20 2015-02-04 18:10:00              65400.0
# 21 2015-02-04 18:10:59              65459.0

# %%
df_0 = df_0.drop(['Occupancy'], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
corr = df_0.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %%
df_1 = full_DatFrame[full_DatFrame['Occupancy'] == 1].drop(['date'], axis=1)
df_1[:5]
# Out:
#    Temperature  Humidity  Light     CO2  HumidityRatio  Occupancy  \
# 1        23.18   27.2720  426.0  721.25       0.004793          1
# 2        23.15   27.2675  429.5  714.00       0.004783          1
# 3        23.15   27.2450  426.0  713.50       0.004779          1
# 4        23.15   27.2000  426.0  708.25       0.004772          1
# 5        23.10   27.2000  426.0  704.50       0.004757          1
#
#              date_obj  secs_since_midnight
# 1 2015-02-04 17:51:00              64260.0
# 2 2015-02-04 17:51:59              64319.0
# 3 2015-02-04 17:53:00              64380.0
# 4 2015-02-04 17:54:00              64440.0
# 5 2015-02-04 17:55:00              64500.0

# %%
df_1 = df_1.drop(['Occupancy'], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
corr = df_1.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %% [markdown]
# As expected, "humidity" and "humidity ratio" are VERY correlated.
# "CO2" seems pretty correlated to "humidity" and "humidity ratio" as well, but not nearly as strong.
#
# Removing "humidity ratio" from consideration, let's see if we can distinguish occupied an unoccupied states with one or two attributes.

# %%
sns.pairplot(full_DatFrame, vars=['Temperature', 'Humidity', 'Light', 'CO2', 'secs_since_midnight'], hue="Occupancy")
plt.show()

# %% [markdown]
# That isn't as pretty as I was hoping.  Haha.
#
# The best single variable that se

# %%
occup_trj = np.array(full_DatFrame['Occupancy'])
trans_index = np.arange(1, len(occup_trj))[occup_trj[:-1] - occup_trj[1:] != 0]

#######################################################

f, axarr = plt.subplots(3, sharex=True, figsize=(12, 10))

axarr[0].fill_between(np.arange(len(full_DatFrame)), 
                      np.max(full_DatFrame['Light']) * full_DatFrame['Occupancy'], 
                      facecolor='yellow', alpha=0.4)
axarr[0].vlines(trans, 0, np.max(full_DatFrame['Light']), color='orange')
axarr[0].plot(full_DatFrame['Light'], color='blue')
axarr[0].set_ylabel('Light')

#######################################################

axarr[1].fill_between(np.arange(len(full_DatFrame)), 
                      np.max(full_DatFrame['CO2']) * full_DatFrame['Occupancy'], 
                      facecolor='yellow', alpha=0.4)
axarr[1].vlines(trans, 0, np.max(full_DatFrame['CO2']), color='orange')
axarr[1].plot(full_DatFrame['CO2'], color='green')
axarr[1].set_ylabel('CO2')

#######################################################

axarr[2].fill_between(np.arange(len(full_DatFrame)), 
                      np.max(full_DatFrame['secs_since_midnight']) * full_DatFrame['Occupancy'], 
                      facecolor='yellow', alpha=0.4)
axarr[2].vlines(trans, 0, np.max(full_DatFrame['secs_since_midnight']), color='orange')
axarr[2].plot(full_DatFrame['secs_since_midnight'], color='red')
axarr[2].set_ylabel('Sec of day')
axarr[2].set_xlabel('Time index')

#######################################################

plt.show()

# %%
full_DatFrame.loc[trans_index, ['date_obj', 'Occupancy']]
# Out:
#                 date_obj  Occupancy
# 16   2015-02-04 18:06:00          1
# 827  2015-02-05 07:37:00          0
# 828  2015-02-05 07:38:00          1
# 831  2015-02-05 07:40:59          0
# 871  2015-02-05 08:21:00          1
# 872  2015-02-05 08:22:00          0
# 991  2015-02-05 10:21:00          1
# 995  2015-02-05 10:25:00          0
# 1122 2015-02-05 12:32:00          1
# 1133 2015-02-05 12:42:59          0
# 1145 2015-02-05 12:55:00          1
# 1154 2015-02-05 13:04:00          0
# 1157 2015-02-05 13:07:00          1
# 1181 2015-02-05 13:31:00          0
# 1183 2015-02-05 13:33:00          1
# 1208 2015-02-05 13:58:00          0
# 1210 2015-02-05 13:59:59          1
# 1221 2015-02-05 14:10:59          0
# 1454 2015-02-05 18:04:00          1
# 2270 2015-02-06 07:40:00          0
# 2271 2015-02-06 07:40:59          1
# 2276 2015-02-06 07:46:00          0
# 2277 2015-02-06 07:46:59          1
# 2279 2015-02-06 07:49:00          0
# 2501 2015-02-06 11:31:00          1
# 2505 2015-02-06 11:35:00          0
# 2583 2015-02-06 12:53:00          1
# 2606 2015-02-06 13:15:59          0
# 2630 2015-02-06 13:40:00          1
# 2636 2015-02-06 13:46:00          0
# 2896 2015-02-06 18:06:00          1
# 6654 2015-02-09 08:44:00          0
# 6657 2015-02-09 08:47:00          1
# 6660 2015-02-09 08:50:00          0
# 6921 2015-02-09 13:11:00          1
# 6944 2015-02-09 13:34:00          0
# 7214 2015-02-09 18:04:00          1
# 8087 2015-02-10 08:37:00          0
# 8089 2015-02-10 08:38:59          1
# 8091 2015-02-10 08:41:00          0

# %%
pd.plotting.autocorrelation_plot(full_DatFrame['Light'])
plt.show()

# %%
pd.plotting.autocorrelation_plot(full_DatFrame['CO2'])
plt.show()
